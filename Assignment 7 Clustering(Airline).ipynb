# %% [markdown]
# # Hierarchical clustering

# %%
# import hierarchical clustering libraries
import numpy as np
import pandas as pd
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
import seaborn as sn

# %%
flight_data = pd.read_csv("C:/Users/Siri/Desktop/Excelr/Assignments/7.Clustering/EastWestAirlines.csv")

# %%
flight_data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
flight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
flight_data2 = flight_data.drop(['ID#'], axis=1)
flight_data2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(flight_data.iloc[:,1:])

# %%
# create dendrogram
plt.figure(figsize=(10, 7))  
dendrogram = sch.dendrogram(sch.linkage(df_norm, method='single'))

# %%
# create dendrogram
plt.figure(figsize=(10, 7))  
dendrogram = sch.dendrogram(sch.linkage(df_norm, method='complete'))

# %%
# create clusters
hc = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'single')
hc
# Out:
# AgglomerativeClustering(linkage='single', n_clusters=4)

# %%
y=pd.DataFrame(hc.fit_predict(df_norm),columns=['clustersid'])
y['clustersid'].value_counts()
# Out:
# 1    2518
# 0    1479
# 3       1
# 2       1
# Name: clustersid, dtype: int64

# %%
# Adding clusters to dataset
df_norm['clustersid']=hc.labels_
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(df_norm['clustersid'],df_norm['Balance'], c=hc.labels_)

# %% [markdown]
# # K means clustering

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist 
from sklearn.preprocessing import StandardScaler

# %%
#IMport the data set
airline = pd.read_csv("C:/Users/Siri/Desktop/Excelr/Assignments/7.Clustering/EastWestAirlines.csv")

# %%
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline_updated=airline.drop(['ID#'],axis=1)
airline_updated
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
# Normalization function 
airline_updatednorm=StandardScaler().fit_transform(airline_updated)

# %% [markdown]
# # #Elbow curve

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(airline_updatednorm)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('Elbow Curve')
plt.xlabel('number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
#Choosing number of clusters as 4

# %%
#Using K=4
C_4=KMeans(4,random_state=30).fit(airline_updatednorm)
C_4
# Out:
# KMeans(n_clusters=4, random_state=30)

# %%
C_4.labels_
# Out:
# array([2, 2, 2, ..., 0, 2, 2])

# %%
#Appending cluster to the data set
airline_new=airline_updated.copy()
airline_new['Clusters'] = C_4.labels_
airline_new
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#Group the data by 4 clusters( K=4)
airline_new.groupby('Clusters').agg(['mean']).reset_index()
# Out:
#   Clusters        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean        mean      mean      mean      mean
# 0        0  116097.747853  136.293521  3.694770  1.002342  1.001561
# 1        1  194447.337209  939.017442  2.203488  1.034884  1.000000
# 2        2   43498.471355   94.440537  1.213750  1.019360  1.000395
# 3        3  138061.400000   78.800000  3.466667  1.000000  4.066667
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  38946.225605   18.719750        327.615144        0.976581
# 1  32260.296512   26.587209       5258.098837       15.348837
# 2   4628.382458    6.883445        200.748716        0.623469
# 3  93927.866667   28.066667        506.666667        1.600000
#
#   Days_since_enroll    Award?
#                mean      mean
# 0       4881.766589  0.641686
# 1       4707.616279  0.813953
# 2       3689.315685  0.201896
# ...

# %%
#Plot the Clusters
plt.figure(figsize=(10,7))
plt.scatter(airline_new['Clusters'], airline_new['Balance'], c= C_4.labels_)

# %%
#Choosing number of clusters as 5

# %%
#Using K=5
C_5=KMeans(5,random_state=30).fit(airline_updatednorm)
C_5
# Out:
# KMeans(n_clusters=5, random_state=30)

# %%
C_5.labels_
# Out:
# array([2, 2, 2, ..., 1, 2, 2])

# %%
#Assign clusters to the data set
airline_new2 = airline_updated.copy()
airline_new2['Clusters']=C_5.labels_
airline_new2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#Group data by Clusters (K=5)
airline_new2.groupby('Clusters').agg(['mean']).reset_index()
# Out:
#   Clusters        Balance   Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean         mean      mean      mean      mean
# 0        0  118476.933333  5361.850000  1.950000  1.000000  1.000000
# 1        1  118261.874396    57.506441  3.731079  1.000000  1.038647
# 2        2   44134.004762    44.064286  1.239683  1.000000  1.000397
# 3        3   68876.581395    23.255814  1.139535  2.348837  1.000000
# 4        4  195242.238806   530.880597  2.328358  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  17258.883333   11.883333        900.466667        2.666667
# 1  40430.095008   19.018519        359.984702        1.073269
# 2   4744.818651    6.921825        208.464286        0.639683
# 3  14689.837209   17.534884        582.627907        2.209302
# 4  35253.156716   28.843284       5882.470149       17.111940
#
#   Days_since_enroll    Award?
# ...

# %%
#Plot the Clusters
plt.figure(figsize=(10,7))
plt.scatter(airline_new2['Clusters'], airline_new2['Balance'], c= C_5.labels_)

# %% [markdown]
# # DBSCAN Algoritham

# %%
#import Libraries
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing  import StandardScaler

# %%
#Import the data set
airline_db = pd.read_csv("C:/Users/Siri/Desktop/Excelr/Assignments/7.Clustering/EastWestAirlines.csv")

# %%
airline_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline_db.drop(['ID#'],axis=1,inplace=True)
airline_db
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Normalize heterogenous numerical data using standard scalar fit transform to dataset
airline_db_norm=StandardScaler().fit_transform(airline_db)
airline_db_norm
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
# DBSCAN Clustering
dbscan=DBSCAN(eps=1,min_samples=11)
dbscan.fit(airline_db_norm)
# Out:
# DBSCAN(eps=1, min_samples=11)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
# Adding clusters to dataset
airline_db['clusters']=dbscan.labels_
airline_db
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_db.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean        mean      mean      mean      mean
# 0       -1  167974.051576  808.249284  2.598854  1.083095  1.070201
# 1        0   52023.848218    2.256929  1.652002  1.000000  1.000000
# 2        1   57233.087549    6.834630  2.594358  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  36208.904011   20.604585       1982.180516        5.744986
# 1   8893.520458    8.338319        100.275407        0.335680
# 2  22444.993191   12.705253        222.057393        0.700389
#
#   Days_since_enroll    Award?
#                mean      mean
# 0       4585.048711  0.648997
# 1       3797.988121  0.000000
# 2       4510.630350  1.000000

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airline_db['clusters'],airline_db['Balance'], c=dbscan.labels_)
